# %%
import pandas as pd

input_red = pd.read_csv('../../results/fechas_117/TERMICA/inputRed.csv', sep=';')
input_red.head()
# Out:
#   CodigoPlanta                                        available_q  \
# 0         TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# 1         TYP2  [22000.0, 22000.0, 22000.0, 22000.0, 22000.0, ...
# 2         TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# 3         TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# 4         TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
#
#             phi       precio_d  \
# 0  0,0000000000  11,2700000000
# 1  0,0000000000  11,2700000000
# 2  0,0000000000  91,9400000000
# 3  0,0000000000  91,9400000000
# 4  0,0000000000  91,9400000000
#
#                                   daily_reman_demand       Fecha  \
# 0  [126600.0, 77740.0, 137720.0, 521300.0, 114130...  2025-08-05
# 1  [126600.0, 77740.0, 137720.0, 521300.0, 114130...  2025-08-05
# 2  [857700.0, 845560.0, 650860.0, 553730.0, 70115...  2025-09-02
# 3  [860580.0, 580630.0, 322051.0700000003, 256310...  2025-09-09
# ...

# %%
input_red['cluster'].value_counts()
# Out:
# cluster
# 5,0000000000     541
# 12,0000000000    510
# 15,0000000000    482
# 9,0000000000     448
# 2,0000000000     442
# 8,0000000000     158
# 1,0000000000     127
# 11,0000000000    126
# 14,0000000000    126
# 4,0000000000      96
# 0,0000000000      94
# 10,0000000000     93
# 7,0000000000      91
# 13,0000000000     90
# 3,0000000000      62
# 6,0000000000      60
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurar datetime
input_red['Fecha'] = pd.to_datetime(input_red['Fecha'])

# Crear fecha sin hora
input_red['Fecha_sola'] = input_red['Fecha'].dt.date

# Extraer hora
input_red['Hora'] = input_red['Fecha'].dt.hour

# %%
input_red
# Out:
#      CodigoPlanta                                        available_q  \
# 0            TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# 1            TYP2  [22000.0, 22000.0, 22000.0, 22000.0, 22000.0, ...
# 2            TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# 3            TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# 4            TYP3  [50000.0, 50000.0, 50000.0, 50000.0, 50000.0, ...
# ...           ...                                                ...
# 4207         TDR1  [47000.0, 47000.0, 47000.0, 47000.0, 47000.0, ...
# 4208         TDR1  [47000.0, 47000.0, 47000.0, 47000.0, 47000.0, ...
# 4209         TDR1  [47000.0, 47000.0, 47000.0, 47000.0, 47000.0, ...
# 4210         TDR1  [47000.0, 47000.0, 47000.0, 47000.0, 47000.0, ...
# 4211         TDR1  [47000.0, 47000.0, 47000.0, 47000.0, 47000.0, ...
#
#                   phi         precio_d  \
# 0        0,0000000000    11,2700000000
# 1        0,0000000000    11,2700000000
# ...

# %%
import pandas as pd
import numpy as np

# convertir string a lista si viene como string
input_red['daily_reman_demand'] = input_red['daily_reman_demand'].apply(
    lambda x: eval(x) if isinstance(x, str) else x
)

# expandir
df_exp = input_red.explode('daily_reman_demand')

# crear indice interno por grupo
df_exp['hora_lista'] = df_exp.groupby(['Fecha_sola','CodigoPlanta']).cumcount()

# ahora sí pivot
df_pivot = df_exp.pivot_table(
    index='Fecha_sola',
    columns='hora_lista',
    values='daily_reman_demand',
    aggfunc='mean'
).sort_index()

# %%
df_pivot
# Out:
# hora_lista         0           1          2         3           4          5   \
# Fecha_sola
# 2025-04-01  238087.97  1032624.41  838456.89  749542.0  1106656.12  406873.38
# 2025-04-02   233350.0    205300.0   951070.0  872530.0   1014760.0   207010.0
# 2025-04-03   895720.0    609450.0   422830.0  348240.0    552490.0   986560.0
# 2025-04-04  270253.61   466977.03  239216.78  149170.0   315984.68  247201.64
# 2025-04-07   530630.0    268940.0   104170.0  406420.0    397260.0   105460.0
# ...               ...         ...        ...       ...         ...        ...
# 2025-09-03   907640.0    634130.0   569640.0  339450.0    342170.0   740620.0
# 2025-09-04   487560.0    261410.0   324070.0  304360.0    369790.0   665120.0
# 2025-09-05   957600.0    748720.0   575140.0  465820.0    676370.0   903960.0
# 2025-09-08    96490.0     92810.0   456530.0  289440.0     90450.0   838610.0
# 2025-09-09   860580.0    580630.0  322051.07  256310.2    484920.0   670770.0
#
# ...

# %%
import matplotlib.pyplot as plt

for col in df_pivot.columns:
    
    plt.figure(figsize=(10,4))
    
    plt.plot(df_pivot.index, df_pivot[col])
    
    plt.title(f'Demanda - hora_lista {col}')
    plt.xlabel('Fecha')
    plt.ylabel('Demanda')
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ Asegurarse de que daily_reman_demand sea lista
input_red['daily_reman_demand'] = input_red['daily_reman_demand'].apply(
    lambda x: eval(x) if isinstance(x, str) else x
)

# 2️⃣ Expandir la lista por fila
df_exp = input_red.explode('daily_reman_demand')

# 3️⃣ Crear hora_lista
df_exp['hora_lista'] = df_exp.groupby(['Fecha_sola','CodigoPlanta']).cumcount()

# 4️⃣ Convertir cluster a string y reemplazar NaN
df_exp['cluster'] = df_exp['cluster'].astype(str).fillna('missing')
clusters = sorted(df_exp['cluster'].unique())

# 5️⃣ Horas únicas
horas = sorted(df_exp['hora_lista'].unique())

# Colores consistentes
colors = {c: plt.cm.tab10(i % 10) for i, c in enumerate(clusters)}

# 6️⃣ Graficar histogramas por hora
for h in horas:
    plt.figure(figsize=(10,5))
    
    for c in clusters:
        datos = df_exp[(df_exp['hora_lista']==h) & (df_exp['cluster']==c)]['daily_reman_demand']
        if len(datos) > 0:
            plt.hist(datos, bins=20, alpha=0.5, label=f'Cluster {c}', color=colors[c])
    
    plt.title(f'Histograma de demanda - Hora {h}')
    plt.xlabel('Demanda')
    plt.ylabel('Frecuencia')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# 1️⃣ Asegurarse de que daily_reman_demand sea lista
# -------------------------------
input_red['daily_reman_demand'] = input_red['daily_reman_demand'].apply(
    lambda x: eval(x) if isinstance(x, str) else x
)

# -------------------------------
# 2️⃣ Expandir la lista por fila
# -------------------------------
df_exp = input_red.explode('daily_reman_demand')

# -------------------------------
# 3️⃣ Crear hora_lista
# -------------------------------
df_exp['hora_lista'] = df_exp.groupby(['Fecha_sola','CodigoPlanta']).cumcount()

# -------------------------------
# 4️⃣ Convertir cluster a string y reemplazar NaN
# -------------------------------
df_exp['cluster'] = df_exp['cluster'].astype(str).fillna('missing')
clusters = sorted(df_exp['cluster'].unique())
horas = sorted(df_exp['hora_lista'].unique())

# Colores consistentes
colors = {c: plt.cm.tab10(i % 10) for i, c in enumerate(clusters)}

# -------------------------------
# 5️⃣ Graficar por hora con subplots por cluster
# -------------------------------
import math

for h in horas:
    n_cols = 2  # subplots por fila
    n_rows = math.ceil(len(clusters)/n_cols)
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 4*n_rows))
    axes = axes.flatten()
    
    for i, c in enumerate(clusters):
        ax = axes[i]
        datos = df_exp[(df_exp['hora_lista']==h) & (df_exp['cluster']==c)]['daily_reman_demand']
        
        if len(datos) > 0:
            ax.hist(datos, bins=20, alpha=0.7, color=colors[c])
        
        ax.set_title(f'Cluster {c}')
        ax.set_xlabel('Demanda')
        ax.set_ylabel('Frecuencia')
    
    # eliminar ejes vacíos
    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])
    
    fig.suptitle(f'Histograma de demanda - Hora {h}', fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

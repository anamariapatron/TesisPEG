# %%
import copy, math, random, numpy as np, torch, torch.nn as nn
import matplotlib.pyplot as plt, os

# ============================================================
# 0. SEED
# ============================================================
def set_seed(seed):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

# ============================================================
# 1. SAMPLER
#    4 players, 3 demand units, 2 supply units each.
#
#    Case "pab_should_win":   costs ~ U(0, 1)
#      High heterogeneity -> large infra-marginal rents under PAC.
#      The cheapest plant (cost ~0) is paid the clearing price (~0.8)
#      under PAC, collecting a huge rent. PAB removes that rent -> cheaper.
#
#    Case "uniform_should_win":  costs ~ U(0.4, 1.0)
#      Concentrated costs near the capacity limit.
#      All players shade toward the expected clearing price,
#      so bid-shading under PAB inflates prices above PAC.
# ============================================================
class ProcurementSampler:
    def __init__(self, scenario_name):
        self.scenario_name = scenario_name
        self.n_players    = 4
        self.demand_units = 3
        self.supply_cap   = 2  # max units per player

        if scenario_name == "pab_should_win":
            self.cost_low, self.cost_high = 0.0, 1.0
        elif scenario_name == "uniform_should_win":
            self.cost_low, self.cost_high = 0.7, 1.0 
        else:
            raise ValueError(f"Unknown scenario: {scenario_name}")

    def sample(self, batch_size):
        c = torch.rand(batch_size, self.n_players, 1) * (self.cost_high - self.cost_low) + self.cost_low
        return c, c.clone()

# ============================================================
# 2. BNE ANALYTICAL FORMULA
#    beta(phi) = 3*(phi+1)^2 / (4*(phi+2))
#    Valid for the PAB equilibrium on cost support [0,1].
# ============================================================
def bne_analytical(phi):
    return 3*(phi+1)**2 / (4*(phi+2))

# ============================================================
# 3. BIDDER NET  (bid = cost + nonneg markup)
# ============================================================
class BidderNet(nn.Module):
    def __init__(self, hidden=10):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(1, hidden), nn.SELU(),
            nn.Linear(hidden, hidden), nn.SELU(),
            nn.Linear(hidden, 1)
        )
    def forward(self, x):
        return x + torch.relu(self.layers(x))

# ============================================================
# 4. PRETRAIN
# ============================================================
def pretrain_truthful(policies, sampler, device, steps=200, batch_size=4096, lr=1e-2):
    optims = [torch.optim.SGD(p.parameters(), lr=lr) for p in policies]
    print("\n>>> Pretraining truthful bidding (bid = cost)...")
    for step in range(steps):
        c, o = sampler.sample(batch_size)
        c, o = c.to(device), o.to(device)
        loss = 0.0
        for i, pol in enumerate(policies):
            optims[i].zero_grad()
            l = ((pol(o[:,i]) - c[:,i])**2).mean()
            l.backward()
            optims[i].step()
            loss += l.item()
        if step % 50 == 0 or step == steps-1:
            print(f"  step {step:4d}/{steps} | loss={loss/len(policies):.8f}")

# %%
# ============================================================
# 5. MULTI-UNIT CLEARING  (supply_cap units per player)
#
#   Sort players by bid (ascending = cheapest first).
#   Allocate up to supply_cap units per player until demand met.
#   Clearing price = bid of the marginal unit (last unit accepted).
#
#   PAC:  all accepted players paid clearing_price per unit
#   PAB:  each accepted player paid own bid per unit
# ============================================================
def procurement_outcome(bids, costs, demand_units, supply_cap, pricing):
    """
    bids, costs: (B, N)
    Returns: accepted_mask (B,N bool), payments (B,N), profits (B,N),
             buyer_cost (B,), clearing_bid (B,), units_sold (B,N)
    """
    B, N = bids.shape
    device = bids.device

    # Sort by bid ascending
    sorted_bids, sort_idx = bids.sort(dim=1)          # (B, N)
    sorted_costs = costs.gather(1, sort_idx)

    # Greedy unit allocation
    remaining = torch.full((B,), float(demand_units), device=device)
    units_sorted = torch.zeros(B, N, device=device)
    for j in range(N):
        give = torch.clamp(remaining, 0.0, float(supply_cap))
        units_sorted[:, j] = give
        remaining = remaining - give

    # Map back to original order
    units_sold = torch.zeros(B, N, device=device)
    units_sold.scatter_(1, sort_idx, units_sorted)

    accepted_mask = units_sold > 0   # (B, N) bool

    # Clearing price = highest accepted bid (marginal unit)
    LARGE = 1e9
    masked = bids.clone()
    masked[~accepted_mask] = -LARGE
    clearing_bid = masked.max(dim=1).values  # (B,)

    # Payments
    if pricing == "uniform":
        pay_per_unit = clearing_bid.unsqueeze(1).expand(B, N)
    else:  # pay_as_bid
        pay_per_unit = bids

    payments = pay_per_unit * units_sold
    profits  = payments - costs * units_sold
    buyer_cost = payments.sum(dim=1)

    return accepted_mask, payments, profits, buyer_cost, clearing_bid, units_sold

# ============================================================
# 6. EVALUATION
# ============================================================
@torch.no_grad()
def evaluate_policies(policies, sampler, device, pricing, eval_batch_size=8192):
    N = sampler.n_players
    c, o = sampler.sample(eval_batch_size)
    c, o = c.to(device), o.to(device)

    bids = torch.cat([policies[i](o[:,i]) for i in range(N)], dim=1)
    c2   = c.squeeze(-1)

    accepted_mask, payments, profits, buyer_cost, clearing, units_sold = \
        procurement_outcome(bids, c2, sampler.demand_units, sampler.supply_cap, pricing)

    acc_f  = accepted_mask.float()
    n_acc  = acc_f.sum().clamp(min=1)

    # Bid curve on cost support grid
    grid_c = torch.linspace(sampler.cost_low, sampler.cost_high, 200, device=device).unsqueeze(1)
    curves = [policies[i](grid_c).squeeze().cpu().numpy() for i in range(N)]
    curves = np.array(curves)

    return {
        "avg_bid":             bids.mean().item(),
        "avg_markup":          (bids - c2).mean().item(),
        "avg_accepted_bid":    (bids*acc_f).sum().item() / n_acc.item(),
        "avg_payment":         payments.sum().item() / n_acc.item(),
        "buyer_cost":          buyer_cost.mean().item(),
        "supplier_profit":     profits.sum(dim=1).mean().item(),
        "clearing_bid":        clearing.mean().item(),
        "curves_all":          curves,
        "curve_mean":          curves.mean(axis=0),
        "grid":                grid_c.squeeze().cpu().numpy(),
    }

# ============================================================
# 7. NPGA PSEUDOGRADIENT
# ============================================================
def flatten_params(model):
    return torch.cat([p.data.flatten() for p in model.parameters()])

def load_flat_params(model, theta):
    off = 0
    for p in model.parameters():
        n = p.numel(); p.data.copy_(theta[off:off+n].view_as(p)); off += n

def npga_gradient(player_idx, policies, sampler, device, pricing, batch_size, pop, sigma):
    pol    = policies[player_idx]
    params = list(pol.parameters())
    flat   = flatten_params(pol)
    d      = flat.numel()
    N      = sampler.n_players

    c, o = sampler.sample(batch_size)
    c, o = c.to(device), o.to(device)
    c2   = c.squeeze(-1)

    # Baseline
    with torch.no_grad():
        bids_b = torch.cat([policies[i](o[:,i]) for i in range(N)], dim=1)
        _, _, prof_b, _, _, _ = procurement_outcome(bids_b, c2,
            sampler.demand_units, sampler.supply_cap, pricing)
        baseline = prof_b[:, player_idx].mean().item()

    # Perturbations
    eps   = torch.randn(pop, d, device=device) * sigma
    fits  = torch.zeros(pop, device=device)

    for p_idx in range(pop):
        # Apply perturbation
        off = 0
        for param in params:
            n = param.numel()
            param.data.add_(eps[p_idx, off:off+n].view_as(param))
            off += n

        with torch.no_grad():
            bids_p = torch.cat([policies[i](o[:,i]) for i in range(N)], dim=1)
            _, _, prof_p, _, _, _ = procurement_outcome(bids_p, c2,
                sampler.demand_units, sampler.supply_cap, pricing)
            fits[p_idx] = prof_p[:, player_idx].mean() - baseline

        # Undo perturbation
        off = 0
        for param in params:
            n = param.numel()
            param.data.sub_(eps[p_idx, off:off+n].view_as(param))
            off += n

    grad_flat = (fits.unsqueeze(1) * eps).sum(0) / (sigma**2 * pop)
    grads, off = [], 0
    for param in params:
        n = param.numel()
        grads.append(grad_flat[off:off+n].view_as(param))
        off += n
    return grads

# ============================================================
# 8. TRAINING LOOP
# ============================================================
def train_npga(scenario_name, pricing, n_epochs=400, pretrain_iters=200,
               batch_size=4096, pop=32, lr=3e-3, sigma=1e-2, hidden=10,
               eval_frequency=50, n_runs=3, eval_batch_size=8192, seed_base=42):

    device  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"\n>>> Device: {device} | Scenario: {scenario_name} | Pricing: {pricing}")

    all_results = []
    for run in range(n_runs):
        set_seed(seed_base + run*100)
        sampler = ProcurementSampler(scenario_name)
        N = sampler.n_players

        print(f"\n{'='*60}")
        print(f"RUN {run+1}/{n_runs} | N={N} | demand={sampler.demand_units} | cap={sampler.supply_cap} | costs~U[{sampler.cost_low},{sampler.cost_high}]")
        print(f"{'='*60}")

        policies = [BidderNet(hidden).to(device) for _ in range(N)]
        optims   = [torch.optim.Adam(p.parameters(), lr=lr) for p in policies]
        pretrain_truthful(policies, sampler, device, pretrain_iters, batch_size)

        res = {k: [] for k in ["epoch","buyer_cost","supplier_profit","avg_bid",
                                "avg_markup","avg_accepted_bid","avg_payment",
                                "clearing_bid","grad_norm","curve_mean","curves_all","grid"]}

        for epoch in range(n_epochs):
            grad_norms = []
            for i in range(N):
                grads = npga_gradient(i, policies, sampler, device,
                                      pricing, batch_size, pop, sigma)
                optims[i].zero_grad()
                for param, g in zip(policies[i].parameters(), grads):
                    param.grad = -g   # Adam minimises, we want to maximise
                nn.utils.clip_grad_norm_(policies[i].parameters(), 1.0)
                optims[i].step()
                grad_norms.append(torch.cat([g.view(-1) for g in grads]).norm().item())

            if epoch % eval_frequency == 0 or epoch == n_epochs-1:
                ev = evaluate_policies(policies, sampler, device, pricing, eval_batch_size)
                res["epoch"].append(epoch)
                for k in ["buyer_cost","supplier_profit","avg_bid","avg_markup",
                          "avg_accepted_bid","avg_payment","clearing_bid"]:
                    res[k].append(ev[k])
                res["grad_norm"].append(float(np.mean(grad_norms)))
                res["curve_mean"].append(ev["curve_mean"])
                res["curves_all"].append(ev["curves_all"])
                res["grid"].append(ev["grid"])
                print(f"[{epoch:4d}] BuyerCost={ev['buyer_cost']:.4f} | "
                      f"AvgBid={ev['avg_bid']:.4f} | "
                      f"Clear={ev['clearing_bid']:.4f} | "
                      f"Markup={ev['avg_markup']:.4f} | "
                      f"GradNorm={np.mean(grad_norms):.2e}")
        all_results.append(res)

    print("\n>>> Training finished.")
    return all_results

# %%
# ============================================================
# 9. COMPARISON
# ============================================================
def mean_path(results_list, metric):
    arr = np.array([r[metric] for r in results_list], dtype=float)
    return arr.mean(0), arr.std(0)

def compare_pricing(res_u, res_p, scenario_name):
    cu = np.mean([r["buyer_cost"][-1] for r in res_u])
    cp = np.mean([r["buyer_cost"][-1] for r in res_p])
    winner = "uniform" if cu < cp else "pay_as_bid"
    print(f"\n{'#'*70}\nSCENARIO: {scenario_name}")
    print(f"Buyer cost | uniform    = {cu:.6f}")
    print(f"Buyer cost | pay_as_bid = {cp:.6f}")
    print(f"WINNER: {winner}\n{'#'*70}")
    return winner

# ============================================================
# 10. PLOTTING  (3 panels: expenditure | avg bid | bid function + BNE)
# ============================================================
def paper_style():
    plt.rcParams.update({
        "figure.dpi": 140, "savefig.dpi": 300,
        "font.size": 11, "axes.titlesize": 12, "axes.labelsize": 11,
        "legend.fontsize": 10, "lines.linewidth": 2.0,
        "axes.spines.top": False, "axes.spines.right": False,
        "legend.frameon": False,
    })

def plot_with_bne(res_uniform, res_pab, title_prefix,
                  show_bne=True, save_dir=None):
    """
    3-panel figure:
      (a) Buyer expenditure over training
      (b) Average bid over training
      (c) Final equilibrium bid function  +  analytical BNE
    """
    paper_style()
    uc, pc = "steelblue", "firebrick"
    bne_c  = "black"

    epochs  = np.array(res_uniform[0]["epoch"])

    u_exp_m, u_exp_s = mean_path(res_uniform, "buyer_cost")
    p_exp_m, p_exp_s = mean_path(res_pab,     "buyer_cost")
    u_bid_m, u_bid_s = mean_path(res_uniform, "avg_bid")
    p_bid_m, p_bid_s = mean_path(res_pab,     "avg_bid")

    # Final bid curve across all runs
    cu = np.array([r["curve_mean"][-1] for r in res_uniform])
    cp = np.array([r["curve_mean"][-1] for r in res_pab])
    grid = res_uniform[0]["grid"][-1]   # cost grid from last eval

    fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))

    # --- (a) Buyer expenditure ---
    ax = axes[0]
    ax.plot(epochs, u_exp_m, label="Uniform",        color=uc)
    ax.fill_between(epochs, u_exp_m-u_exp_s, u_exp_m+u_exp_s, alpha=.2, color=uc)
    ax.plot(epochs, p_exp_m, label="Discriminatory", color=pc)
    ax.fill_between(epochs, p_exp_m-p_exp_s, p_exp_m+p_exp_s, alpha=.2, color=pc)
    ax.set_title("(a) Auctioneer's expenditure")
    ax.set_xlabel("Epoch"); ax.set_ylabel("Auctioneer's expenditure")
    ax.legend()

    # --- (b) Average bid ---
    ax = axes[1]
    ax.plot(epochs, u_bid_m, label="Uniform",        color=uc)
    ax.fill_between(epochs, u_bid_m-u_bid_s, u_bid_m+u_bid_s, alpha=.2, color=uc)
    ax.plot(epochs, p_bid_m, label="Discriminatory", color=pc)
    ax.fill_between(epochs, p_bid_m-p_bid_s, p_bid_m+p_bid_s, alpha=.2, color=pc)
    ax.set_title("(b) Average bid")
    ax.set_xlabel("Epoch"); ax.set_ylabel("Mean bid")
    ax.legend()

    # --- (c) Bid function + BNE ---
    ax = axes[2]
    ax.plot(grid, cu.mean(0), label="Uniform (learned)",        color=uc)
    ax.fill_between(grid, cu.mean(0)-cu.std(0), cu.mean(0)+cu.std(0), alpha=.2, color=uc)
    ax.plot(grid, cp.mean(0), label="Discriminatory (learned)", color=pc)
    ax.fill_between(grid, cp.mean(0)-cp.std(0), cp.mean(0)+cp.std(0), alpha=.2, color=pc)
    ax.plot(grid, grid, "k--", lw=1, label="Truthful: $b=\\phi$")
    if show_bne:
        bne_vals = bne_analytical(grid)
        ax.plot(grid, bne_vals, color=bne_c, lw=2, ls="-.",
                label=r"BNE: $\beta(\phi)=\frac{3(\phi+1)^2}{4(\phi+2)}$")
    ax.set_title("(c) Equilibrium bid function")
    ax.set_xlabel("Marginal cost $\\phi$"); ax.set_ylabel("Bid $b(\\phi)$")
    ax.legend(fontsize=8)

    fig.suptitle(title_prefix, y=1.02, fontsize=13)
    plt.tight_layout()

    if save_dir:
        os.makedirs(save_dir, exist_ok=True)
        safe = title_prefix.lower().replace(" ","_").replace(":","").replace("(","").replace(")","")
        fig.savefig(os.path.join(save_dir, f"{safe}.pdf"), bbox_inches="tight")
        fig.savefig(os.path.join(save_dir, f"{safe}.png"), bbox_inches="tight")
    plt.show()

# %%
# ============================================================
# 11. RUN
# ============================================================
if __name__ == "__main__":
    common = dict(
    n_epochs=600,        # ↑ más épocas → mejor convergencia al equilibrio
    pretrain_iters=200,  # OK
    batch_size=4096,     # OK
    pop=64,              # ↑ más población → gradiente NPGA más preciso
    lr=3e-3,             # OK
    sigma=1e-2,          # ← CLAVE: muy pequeño → exploración insuficiente
                         #           muy grande → gradiente ruidoso
    hidden=10,           # OK para este problema
    eval_frequency=50,
    n_runs=3,            # ↑ más runs → resultado más confiable
    eval_batch_size=8192,
)

    # Case 1: U(0,1) — PAB should win
    print("\n" + "="*60 + "\nCASE 1: U(0,1)  →  PAB expected to win\n" + "="*60)
    res_u1 = train_npga("pab_should_win",     "uniform",    **common)
    res_p1 = train_npga("pab_should_win",     "pay_as_bid", **common)
    compare_pricing(res_u1, res_p1, "pab_should_win [U(0,1)]")
    # Plots
    plot_with_bne(
        res_u1, res_p1,
        title_prefix="Case 1: discriminatory pricing cheaper",
        show_bne=True,
        save_dir="simulationPABvsPAC_v3"
    )
# Out:
# ============================================================
# CASE 1: U(0,1)  →  PAB expected to win
# ============================================================
#
# >>> Device: cuda | Scenario: pab_should_win | Pricing: uniform
#
# ============================================================
# RUN 1/3 | N=4 | demand=3 | cap=2 | costs~U[0.0,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.00000000
#   step   50/200 | loss=0.00000000
#   step  100/200 | loss=0.00000000
#   step  150/200 | loss=0.00000000
#   step  199/200 | loss=0.00000000
# [   0] BuyerCost=1.2022 | AvgBid=0.5012 | Clear=0.4007 | Markup=0.0000 | GradNorm=1.35e-04
# [  50] BuyerCost=1.3070 | AvgBid=0.5383 | Clear=0.4357 | Markup=0.0371 | GradNorm=2.93e-02
# [ 100] BuyerCost=1.3008 | AvgBid=0.5312 | Clear=0.4336 | Markup=0.0317 | GradNorm=4.25e-02
# [ 150] BuyerCost=1.3082 | AvgBid=0.5316 | Clear=0.4361 | Markup=0.0308 | GradNorm=3.80e-02
# [ 200] BuyerCost=1.3068 | AvgBid=0.5341 | Clear=0.4356 | Markup=0.0360 | GradNorm=2.89e-02
# [ 250] BuyerCost=1.3001 | AvgBid=0.5290 | Clear=0.4334 | Markup=0.0333 | GradNorm=3.52e-02
# [ 300] BuyerCost=1.3066 | AvgBid=0.5309 | Clear=0.4355 | Markup=0.0301 | GradNorm=3.07e-02
# [ 350] BuyerCost=1.2945 | AvgBid=0.5278 | Clear=0.4315 | Markup=0.0282 | GradNorm=3.67e-02
# [ 400] BuyerCost=1.2964 | AvgBid=0.5287 | Clear=0.4321 | Markup=0.0310 | GradNorm=2.87e-02
# [ 450] BuyerCost=1.3179 | AvgBid=0.5340 | Clear=0.4393 | Markup=0.0313 | GradNorm=3.53e-02
# [ 500] BuyerCost=1.2905 | AvgBid=0.5268 | Clear=0.4302 | Markup=0.0312 | GradNorm=1.91e-02
# [ 550] BuyerCost=1.3049 | AvgBid=0.5287 | Clear=0.4350 | Markup=0.0290 | GradNorm=2.43e-02
# [ 599] BuyerCost=1.2813 | AvgBid=0.5222 | Clear=0.4271 | Markup=0.0278 | GradNorm=5.40e-02
#
# ============================================================
# RUN 2/3 | N=4 | demand=3 | cap=2 | costs~U[0.0,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.05186047
#   step   50/200 | loss=0.00003649
#   step  100/200 | loss=0.00000425
#   step  150/200 | loss=0.00000129
#   step  199/200 | loss=0.00000045
# [   0] BuyerCost=1.2113 | AvgBid=0.5053 | Clear=0.4038 | Markup=0.0020 | GradNorm=2.12e-02
# [  50] BuyerCost=1.5406 | AvgBid=0.6291 | Clear=0.5135 | Markup=0.1273 | GradNorm=9.89e-02
# [ 100] BuyerCost=1.5011 | AvgBid=0.6007 | Clear=0.5004 | Markup=0.1036 | GradNorm=1.16e-01
# [ 150] BuyerCost=1.4993 | AvgBid=0.5985 | Clear=0.4998 | Markup=0.0981 | GradNorm=1.24e-01
# [ 200] BuyerCost=1.5074 | AvgBid=0.6019 | Clear=0.5025 | Markup=0.1021 | GradNorm=1.50e-01
# [ 250] BuyerCost=1.5133 | AvgBid=0.6037 | Clear=0.5044 | Markup=0.1035 | GradNorm=1.34e-01
# [ 300] BuyerCost=1.4896 | AvgBid=0.5961 | Clear=0.4965 | Markup=0.0989 | GradNorm=1.17e-01
# [ 350] BuyerCost=1.5030 | AvgBid=0.5968 | Clear=0.5010 | Markup=0.0984 | GradNorm=1.53e-01
# [ 400] BuyerCost=1.4999 | AvgBid=0.5982 | Clear=0.5000 | Markup=0.1005 | GradNorm=1.65e-01
# [ 450] BuyerCost=1.5039 | AvgBid=0.5982 | Clear=0.5013 | Markup=0.0986 | GradNorm=1.47e-01
# [ 500] BuyerCost=1.5311 | AvgBid=0.6063 | Clear=0.5104 | Markup=0.1060 | GradNorm=1.23e-01
# [ 550] BuyerCost=1.5284 | AvgBid=0.6031 | Clear=0.5095 | Markup=0.0998 | GradNorm=1.13e-01
# [ 599] BuyerCost=1.5391 | AvgBid=0.6088 | Clear=0.5131 | Markup=0.1062 | GradNorm=9.66e-02
#
# ============================================================
# RUN 3/3 | N=4 | demand=3 | cap=2 | costs~U[0.0,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.13857310
#   step   50/200 | loss=0.00002327
#   step  100/200 | loss=0.00000358
#   step  150/200 | loss=0.00000129
#   step  199/200 | loss=0.00000058
# [   0] BuyerCost=1.2245 | AvgBid=0.5122 | Clear=0.4082 | Markup=0.0101 | GradNorm=3.94e-01
# [  50] BuyerCost=1.5881 | AvgBid=0.6345 | Clear=0.5294 | Markup=0.1332 | GradNorm=1.45e-01
# [ 100] BuyerCost=1.6377 | AvgBid=0.6482 | Clear=0.5459 | Markup=0.1480 | GradNorm=2.17e-01
# [ 150] BuyerCost=1.6299 | AvgBid=0.6405 | Clear=0.5433 | Markup=0.1385 | GradNorm=1.88e-01
# [ 200] BuyerCost=1.5989 | AvgBid=0.6326 | Clear=0.5330 | Markup=0.1327 | GradNorm=1.68e-01
# [ 250] BuyerCost=1.5927 | AvgBid=0.6304 | Clear=0.5309 | Markup=0.1296 | GradNorm=2.01e-01
# [ 300] BuyerCost=1.5978 | AvgBid=0.6320 | Clear=0.5326 | Markup=0.1327 | GradNorm=1.66e-01
# [ 350] BuyerCost=1.5987 | AvgBid=0.6328 | Clear=0.5329 | Markup=0.1337 | GradNorm=1.50e-01
# [ 400] BuyerCost=1.6366 | AvgBid=0.6414 | Clear=0.5455 | Markup=0.1378 | GradNorm=2.00e-01
# [ 450] BuyerCost=1.6037 | AvgBid=0.6313 | Clear=0.5346 | Markup=0.1324 | GradNorm=2.01e-01
# [ 500] BuyerCost=1.5939 | AvgBid=0.6268 | Clear=0.5313 | Markup=0.1282 | GradNorm=2.03e-01
# [ 550] BuyerCost=1.6102 | AvgBid=0.6308 | Clear=0.5367 | Markup=0.1321 | GradNorm=1.95e-01
# [ 599] BuyerCost=1.5987 | AvgBid=0.6271 | Clear=0.5329 | Markup=0.1277 | GradNorm=1.61e-01
#
# >>> Training finished.
#
# >>> Device: cuda | Scenario: pab_should_win | Pricing: pay_as_bid
#
# ============================================================
# RUN 1/3 | N=4 | demand=3 | cap=2 | costs~U[0.0,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.00000000
#   step   50/200 | loss=0.00000000
#   step  100/200 | loss=0.00000000
#   step  150/200 | loss=0.00000000
#   step  199/200 | loss=0.00000000
# [   0] BuyerCost=0.8080 | AvgBid=0.5012 | Clear=0.4007 | Markup=0.0000 | GradNorm=1.35e-04
# [  50] BuyerCost=0.9384 | AvgBid=0.6007 | Clear=0.4620 | Markup=0.0996 | GradNorm=5.56e-02
# [ 100] BuyerCost=0.9413 | AvgBid=0.5495 | Clear=0.4583 | Markup=0.0501 | GradNorm=8.11e-02
# [ 150] BuyerCost=0.9465 | AvgBid=0.5481 | Clear=0.4622 | Markup=0.0473 | GradNorm=4.80e-02
# [ 200] BuyerCost=0.9337 | AvgBid=0.5444 | Clear=0.4574 | Markup=0.0463 | GradNorm=3.62e-02
# [ 250] BuyerCost=0.9306 | AvgBid=0.5397 | Clear=0.4551 | Markup=0.0440 | GradNorm=3.17e-02
# [ 300] BuyerCost=0.9382 | AvgBid=0.5433 | Clear=0.4583 | Markup=0.0426 | GradNorm=2.38e-02
# [ 350] BuyerCost=0.9368 | AvgBid=0.5407 | Clear=0.4540 | Markup=0.0411 | GradNorm=7.01e-02
# [ 400] BuyerCost=0.9323 | AvgBid=0.5418 | Clear=0.4553 | Markup=0.0441 | GradNorm=2.62e-02
# [ 450] BuyerCost=0.9537 | AvgBid=0.5521 | Clear=0.4653 | Markup=0.0494 | GradNorm=3.55e-02
# [ 500] BuyerCost=0.9245 | AvgBid=0.5395 | Clear=0.4525 | Markup=0.0439 | GradNorm=3.18e-02
# [ 550] BuyerCost=0.9450 | AvgBid=0.5441 | Clear=0.4596 | Markup=0.0444 | GradNorm=3.74e-02
# [ 599] BuyerCost=0.9299 | AvgBid=0.5388 | Clear=0.4527 | Markup=0.0444 | GradNorm=3.24e-02
#
# ============================================================
# RUN 2/3 | N=4 | demand=3 | cap=2 | costs~U[0.0,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.05186047
#   step   50/200 | loss=0.00003649
#   step  100/200 | loss=0.00000425
#   step  150/200 | loss=0.00000129
#   step  199/200 | loss=0.00000045
# [   0] BuyerCost=0.8123 | AvgBid=0.5052 | Clear=0.4037 | Markup=0.0019 | GradNorm=2.84e-02
# [  50] BuyerCost=1.4614 | AvgBid=0.7835 | Clear=0.6705 | Markup=0.2816 | GradNorm=2.73e-01
# [ 100] BuyerCost=1.3656 | AvgBid=0.6677 | Clear=0.6048 | Markup=0.1706 | GradNorm=2.85e-01
# [ 150] BuyerCost=1.3352 | AvgBid=0.6304 | Clear=0.5774 | Markup=0.1299 | GradNorm=3.56e-01
# [ 200] BuyerCost=1.3756 | AvgBid=0.6544 | Clear=0.5994 | Markup=0.1545 | GradNorm=4.91e-01
# [ 250] BuyerCost=1.3639 | AvgBid=0.6496 | Clear=0.5954 | Markup=0.1494 | GradNorm=3.05e-01
# [ 300] BuyerCost=1.3476 | AvgBid=0.6419 | Clear=0.5855 | Markup=0.1448 | GradNorm=2.63e-01
# [ 350] BuyerCost=1.3433 | AvgBid=0.6359 | Clear=0.5846 | Markup=0.1376 | GradNorm=3.94e-01
# [ 400] BuyerCost=1.3314 | AvgBid=0.6354 | Clear=0.5798 | Markup=0.1377 | GradNorm=3.35e-01
# [ 450] BuyerCost=1.3367 | AvgBid=0.6328 | Clear=0.5808 | Markup=0.1331 | GradNorm=3.90e-01
# [ 500] BuyerCost=1.3467 | AvgBid=0.6374 | Clear=0.5848 | Markup=0.1371 | GradNorm=3.24e-01
# [ 550] BuyerCost=1.3655 | AvgBid=0.6454 | Clear=0.5937 | Markup=0.1420 | GradNorm=3.10e-01
# [ 599] BuyerCost=1.3371 | AvgBid=0.6339 | Clear=0.5807 | Markup=0.1314 | GradNorm=3.88e-01
#
# ============================================================
# RUN 3/3 | N=4 | demand=3 | cap=2 | costs~U[0.0,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.13857310
#   step   50/200 | loss=0.00002327
#   step  100/200 | loss=0.00000358
#   step  150/200 | loss=0.00000129
#   step  199/200 | loss=0.00000058
# [   0] BuyerCost=0.8290 | AvgBid=0.5106 | Clear=0.4067 | Markup=0.0085 | GradNorm=1.32e+00
# [  50] BuyerCost=1.8853 | AvgBid=0.8088 | Clear=0.7303 | Markup=0.3075 | GradNorm=6.67e-01
# [ 100] BuyerCost=1.6746 | AvgBid=0.6942 | Clear=0.6372 | Markup=0.1940 | GradNorm=8.59e-01
# [ 150] BuyerCost=1.6640 | AvgBid=0.6841 | Clear=0.6304 | Markup=0.1821 | GradNorm=8.51e-01
# [ 200] BuyerCost=1.5694 | AvgBid=0.6559 | Clear=0.5962 | Markup=0.1560 | GradNorm=7.59e-01
# [ 250] BuyerCost=1.6019 | AvgBid=0.6658 | Clear=0.6075 | Markup=0.1649 | GradNorm=7.93e-01
# [ 300] BuyerCost=1.5655 | AvgBid=0.6591 | Clear=0.5984 | Markup=0.1599 | GradNorm=6.05e-01
# [ 350] BuyerCost=1.6131 | AvgBid=0.6726 | Clear=0.6138 | Markup=0.1735 | GradNorm=6.68e-01
# [ 400] BuyerCost=1.5967 | AvgBid=0.6673 | Clear=0.6094 | Markup=0.1637 | GradNorm=7.22e-01
# [ 450] BuyerCost=1.5765 | AvgBid=0.6589 | Clear=0.5983 | Markup=0.1599 | GradNorm=6.81e-01
# [ 500] BuyerCost=1.6024 | AvgBid=0.6668 | Clear=0.6074 | Markup=0.1682 | GradNorm=6.29e-01
# [ 550] BuyerCost=1.5921 | AvgBid=0.6668 | Clear=0.6075 | Markup=0.1680 | GradNorm=6.51e-01
# [ 599] BuyerCost=1.5975 | AvgBid=0.6681 | Clear=0.6076 | Markup=0.1686 | GradNorm=6.28e-01
#
# >>> Training finished.
#
# ######################################################################
# SCENARIO: pab_should_win [U(0,1)]
# Buyer cost | uniform    = 1.473025
# Buyer cost | pay_as_bid = 1.288136
# WINNER: pay_as_bid
# ######################################################################

# %%
 # Case 2: U(0, 10) — Uniform should win
print("\n" + "="*60 + "\nCASE 2: U(0, 10)  →  Uniform expected to win\n" + "="*60)
res_u2 = train_npga("uniform_should_win", "uniform",    **common)
res_p2 = train_npga("uniform_should_win", "pay_as_bid", **common)
compare_pricing(res_u2, res_p2, "uniform_should_win [U(0, 10)]")
plot_with_bne(
        res_u2, res_p2,
        title_prefix="Case 2: Uniform pricing cheaper",
        show_bne=False,   # BNE formula is for U(0,1), not applicable here
        save_dir="simulationPABvsPAC_v3"
    )
# Out:
# ============================================================
# CASE 2: U(0, 10)  →  Uniform expected to win
# ============================================================
#
# >>> Device: cuda | Scenario: uniform_should_win | Pricing: uniform
#
# ============================================================
# RUN 1/3 | N=4 | demand=3 | cap=2 | costs~U[0.7,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.00000000
#   step   50/200 | loss=0.00000000
#   step  100/200 | loss=0.00000000
#   step  150/200 | loss=0.00000000
#   step  199/200 | loss=0.00000000
# [   0] BuyerCost=2.4607 | AvgBid=0.8503 | Clear=0.8202 | Markup=0.0000 | GradNorm=3.41e-03
# [  50] BuyerCost=2.4947 | AvgBid=0.8666 | Clear=0.8316 | Markup=0.0163 | GradNorm=6.33e-02
# [ 100] BuyerCost=2.4792 | AvgBid=0.8602 | Clear=0.8264 | Markup=0.0103 | GradNorm=7.39e-02
# [ 150] BuyerCost=2.4907 | AvgBid=0.8634 | Clear=0.8302 | Markup=0.0131 | GradNorm=8.16e-02
# [ 200] BuyerCost=2.4886 | AvgBid=0.8630 | Clear=0.8295 | Markup=0.0135 | GradNorm=6.34e-02
# [ 250] BuyerCost=2.4872 | AvgBid=0.8611 | Clear=0.8291 | Markup=0.0124 | GradNorm=5.57e-02
# [ 300] BuyerCost=2.4779 | AvgBid=0.8565 | Clear=0.8260 | Markup=0.0063 | GradNorm=6.83e-02
# [ 350] BuyerCost=2.4822 | AvgBid=0.8587 | Clear=0.8274 | Markup=0.0088 | GradNorm=8.76e-02
# [ 400] BuyerCost=2.4885 | AvgBid=0.8608 | Clear=0.8295 | Markup=0.0115 | GradNorm=8.12e-02
# [ 450] BuyerCost=2.4879 | AvgBid=0.8599 | Clear=0.8293 | Markup=0.0091 | GradNorm=7.14e-02
# [ 500] BuyerCost=2.4796 | AvgBid=0.8583 | Clear=0.8265 | Markup=0.0097 | GradNorm=9.40e-02
# [ 550] BuyerCost=2.4908 | AvgBid=0.8608 | Clear=0.8303 | Markup=0.0109 | GradNorm=6.12e-02
# [ 599] BuyerCost=2.4887 | AvgBid=0.8601 | Clear=0.8296 | Markup=0.0118 | GradNorm=8.07e-02
#
# ============================================================
# RUN 2/3 | N=4 | demand=3 | cap=2 | costs~U[0.7,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.07630029
#   step   50/200 | loss=0.00000309
#   step  100/200 | loss=0.00000032
#   step  150/200 | loss=0.00000009
#   step  199/200 | loss=0.00000003
# [   0] BuyerCost=2.4711 | AvgBid=0.8556 | Clear=0.8237 | Markup=0.0046 | GradNorm=1.27e-01
# [  50] BuyerCost=2.5486 | AvgBid=0.8857 | Clear=0.8495 | Markup=0.0351 | GradNorm=2.58e-01
# [ 100] BuyerCost=2.5528 | AvgBid=0.8868 | Clear=0.8509 | Markup=0.0376 | GradNorm=2.70e-01
# [ 150] BuyerCost=2.5676 | AvgBid=0.8916 | Clear=0.8559 | Markup=0.0415 | GradNorm=2.87e-01
# [ 200] BuyerCost=2.5521 | AvgBid=0.8858 | Clear=0.8507 | Markup=0.0358 | GradNorm=3.17e-01
# [ 250] BuyerCost=2.5622 | AvgBid=0.8887 | Clear=0.8541 | Markup=0.0387 | GradNorm=2.87e-01
# [ 300] BuyerCost=2.5518 | AvgBid=0.8853 | Clear=0.8506 | Markup=0.0361 | GradNorm=2.33e-01
# [ 350] BuyerCost=2.5489 | AvgBid=0.8834 | Clear=0.8496 | Markup=0.0339 | GradNorm=2.98e-01
# [ 400] BuyerCost=2.5578 | AvgBid=0.8862 | Clear=0.8526 | Markup=0.0369 | GradNorm=3.50e-01
# [ 450] BuyerCost=2.5525 | AvgBid=0.8842 | Clear=0.8508 | Markup=0.0343 | GradNorm=2.70e-01
# [ 500] BuyerCost=2.5639 | AvgBid=0.8872 | Clear=0.8546 | Markup=0.0371 | GradNorm=3.05e-01
# [ 550] BuyerCost=2.5599 | AvgBid=0.8864 | Clear=0.8533 | Markup=0.0354 | GradNorm=2.68e-01
# [ 599] BuyerCost=2.5676 | AvgBid=0.8889 | Clear=0.8559 | Markup=0.0382 | GradNorm=2.50e-01
#
# ============================================================
# RUN 3/3 | N=4 | demand=3 | cap=2 | costs~U[0.7,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.14225129
#   step   50/200 | loss=0.00000136
#   step  100/200 | loss=0.00000015
#   step  150/200 | loss=0.00000005
#   step  199/200 | loss=0.00000002
# [   0] BuyerCost=2.5247 | AvgBid=0.8717 | Clear=0.8416 | Markup=0.0211 | GradNorm=3.94e-01
# [  50] BuyerCost=2.5574 | AvgBid=0.8828 | Clear=0.8525 | Markup=0.0324 | GradNorm=4.18e-01
# [ 100] BuyerCost=2.5825 | AvgBid=0.8918 | Clear=0.8608 | Markup=0.0417 | GradNorm=5.33e-01
# [ 150] BuyerCost=2.5919 | AvgBid=0.8946 | Clear=0.8640 | Markup=0.0440 | GradNorm=4.10e-01
# [ 200] BuyerCost=2.5711 | AvgBid=0.8879 | Clear=0.8570 | Markup=0.0379 | GradNorm=4.24e-01
# [ 250] BuyerCost=2.5617 | AvgBid=0.8849 | Clear=0.8539 | Markup=0.0347 | GradNorm=3.90e-01
# [ 300] BuyerCost=2.5777 | AvgBid=0.8908 | Clear=0.8592 | Markup=0.0410 | GradNorm=4.60e-01
# [ 350] BuyerCost=2.5671 | AvgBid=0.8879 | Clear=0.8557 | Markup=0.0382 | GradNorm=3.97e-01
# [ 400] BuyerCost=2.6007 | AvgBid=0.8979 | Clear=0.8669 | Markup=0.0468 | GradNorm=4.23e-01
# [ 450] BuyerCost=2.5941 | AvgBid=0.8971 | Clear=0.8647 | Markup=0.0474 | GradNorm=4.59e-01
# [ 500] BuyerCost=2.5734 | AvgBid=0.8892 | Clear=0.8578 | Markup=0.0396 | GradNorm=4.25e-01
# [ 550] BuyerCost=2.5779 | AvgBid=0.8903 | Clear=0.8593 | Markup=0.0407 | GradNorm=4.00e-01
# [ 599] BuyerCost=2.5757 | AvgBid=0.8904 | Clear=0.8586 | Markup=0.0406 | GradNorm=3.79e-01
#
# >>> Training finished.
#
# >>> Device: cuda | Scenario: uniform_should_win | Pricing: pay_as_bid
#
# ============================================================
# RUN 1/3 | N=4 | demand=3 | cap=2 | costs~U[0.7,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.00000000
#   step   50/200 | loss=0.00000000
#   step  100/200 | loss=0.00000000
#   step  150/200 | loss=0.00000000
#   step  199/200 | loss=0.00000000
# [   0] BuyerCost=2.3424 | AvgBid=0.8503 | Clear=0.8202 | Markup=0.0000 | GradNorm=4.72e-03
# [  50] BuyerCost=2.3896 | AvgBid=0.8862 | Clear=0.8425 | Markup=0.0358 | GradNorm=6.24e-02
# [ 100] BuyerCost=2.3825 | AvgBid=0.8784 | Clear=0.8388 | Markup=0.0285 | GradNorm=8.09e-02
# [ 150] BuyerCost=2.3838 | AvgBid=0.8775 | Clear=0.8397 | Markup=0.0272 | GradNorm=1.00e-01
# [ 200] BuyerCost=2.3808 | AvgBid=0.8749 | Clear=0.8387 | Markup=0.0255 | GradNorm=1.05e-01
# [ 250] BuyerCost=2.3798 | AvgBid=0.8719 | Clear=0.8377 | Markup=0.0232 | GradNorm=6.80e-02
# [ 300] BuyerCost=2.3784 | AvgBid=0.8682 | Clear=0.8366 | Markup=0.0179 | GradNorm=1.68e-01
# [ 350] BuyerCost=2.3796 | AvgBid=0.8675 | Clear=0.8362 | Markup=0.0176 | GradNorm=1.92e-01
# [ 400] BuyerCost=2.3824 | AvgBid=0.8700 | Clear=0.8388 | Markup=0.0207 | GradNorm=1.22e-01
# [ 450] BuyerCost=2.3825 | AvgBid=0.8673 | Clear=0.8379 | Markup=0.0164 | GradNorm=1.13e-01
# [ 500] BuyerCost=2.3765 | AvgBid=0.8651 | Clear=0.8357 | Markup=0.0164 | GradNorm=1.77e-01
# [ 550] BuyerCost=2.3846 | AvgBid=0.8657 | Clear=0.8388 | Markup=0.0158 | GradNorm=8.40e-02
# [ 599] BuyerCost=2.3813 | AvgBid=0.8642 | Clear=0.8374 | Markup=0.0159 | GradNorm=1.02e-01
#
# ============================================================
# RUN 2/3 | N=4 | demand=3 | cap=2 | costs~U[0.7,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.07630029
#   step   50/200 | loss=0.00000309
#   step  100/200 | loss=0.00000032
#   step  150/200 | loss=0.00000009
#   step  199/200 | loss=0.00000003
# [   0] BuyerCost=2.3472 | AvgBid=0.8550 | Clear=0.8233 | Markup=0.0040 | GradNorm=3.89e-01
# [  50] BuyerCost=2.5368 | AvgBid=0.9386 | Clear=0.9014 | Markup=0.0880 | GradNorm=4.95e-01
# [ 100] BuyerCost=2.5466 | AvgBid=0.9412 | Clear=0.9069 | Markup=0.0921 | GradNorm=4.53e-01
# [ 150] BuyerCost=2.5424 | AvgBid=0.9335 | Clear=0.9016 | Markup=0.0834 | GradNorm=5.74e-01
# [ 200] BuyerCost=2.5477 | AvgBid=0.9340 | Clear=0.9034 | Markup=0.0841 | GradNorm=7.98e-01
# [ 250] BuyerCost=2.5443 | AvgBid=0.9315 | Clear=0.9023 | Markup=0.0815 | GradNorm=5.39e-01
# [ 300] BuyerCost=2.5233 | AvgBid=0.9188 | Clear=0.8909 | Markup=0.0697 | GradNorm=6.57e-01
# [ 350] BuyerCost=2.5306 | AvgBid=0.9191 | Clear=0.8937 | Markup=0.0696 | GradNorm=8.18e-01
# [ 400] BuyerCost=2.5334 | AvgBid=0.9187 | Clear=0.8946 | Markup=0.0694 | GradNorm=7.14e-01
# [ 450] BuyerCost=2.5225 | AvgBid=0.9110 | Clear=0.8883 | Markup=0.0611 | GradNorm=7.73e-01
# [ 500] BuyerCost=2.5483 | AvgBid=0.9217 | Clear=0.9003 | Markup=0.0716 | GradNorm=8.45e-01
# [ 550] BuyerCost=2.5391 | AvgBid=0.9169 | Clear=0.8957 | Markup=0.0659 | GradNorm=7.78e-01
# [ 599] BuyerCost=2.5478 | AvgBid=0.9205 | Clear=0.8997 | Markup=0.0698 | GradNorm=8.51e-01
#
# ============================================================
# RUN 3/3 | N=4 | demand=3 | cap=2 | costs~U[0.7,1.0]
# ============================================================
#
# >>> Pretraining truthful bidding (bid = cost)...
#   step    0/200 | loss=0.14225129
#   step   50/200 | loss=0.00000136
#   step  100/200 | loss=0.00000015
#   step  150/200 | loss=0.00000005
#   step  199/200 | loss=0.00000002
# [   0] BuyerCost=2.4144 | AvgBid=0.8724 | Clear=0.8428 | Markup=0.0218 | GradNorm=1.81e+00
# [  50] BuyerCost=2.6880 | AvgBid=0.9592 | Clear=0.9318 | Markup=0.1088 | GradNorm=1.28e+00
# [ 100] BuyerCost=2.7126 | AvgBid=0.9635 | Clear=0.9381 | Markup=0.1134 | GradNorm=1.84e+00
# [ 150] BuyerCost=2.6982 | AvgBid=0.9561 | Clear=0.9319 | Markup=0.1055 | GradNorm=1.58e+00
# [ 200] BuyerCost=2.6491 | AvgBid=0.9367 | Clear=0.9131 | Markup=0.0867 | GradNorm=1.63e+00
# [ 250] BuyerCost=2.6563 | AvgBid=0.9365 | Clear=0.9144 | Markup=0.0862 | GradNorm=1.56e+00
# [ 300] BuyerCost=2.6278 | AvgBid=0.9269 | Clear=0.9039 | Markup=0.0771 | GradNorm=1.65e+00
# [ 350] BuyerCost=2.6473 | AvgBid=0.9332 | Clear=0.9097 | Markup=0.0835 | GradNorm=1.64e+00
# [ 400] BuyerCost=2.6248 | AvgBid=0.9238 | Clear=0.9032 | Markup=0.0727 | GradNorm=1.79e+00
# [ 450] BuyerCost=2.6179 | AvgBid=0.9204 | Clear=0.9004 | Markup=0.0707 | GradNorm=1.68e+00
# [ 500] BuyerCost=2.6223 | AvgBid=0.9193 | Clear=0.9000 | Markup=0.0698 | GradNorm=1.67e+00
# [ 550] BuyerCost=2.6553 | AvgBid=0.9302 | Clear=0.9109 | Markup=0.0806 | GradNorm=1.92e+00
# [ 599] BuyerCost=2.5991 | AvgBid=0.9115 | Clear=0.8921 | Markup=0.0616 | GradNorm=1.78e+00
#
# >>> Training finished.
#
# ######################################################################
# SCENARIO: uniform_should_win [U(0, 10)]
# Buyer cost | uniform    = 2.544015
# Buyer cost | pay_as_bid = 2.509428
# WINNER: pay_as_bid
# ######################################################################

# %%
#librerias
import pandas as pd
import numpy as np

# %%
#hacer una grafica de

# %%
#cargar archivos
df_final = pd.read_csv("../datos/procesado/df_final.csv")
df_transado =pd.read_csv("../datos/procesado/df_despacho_agg.csv")

# %%
df_bolsa_filtrado.describe()
# Out:
#               Valor
# count  27600.000000
# mean     153.590278
# std      127.437081
# min       95.060000
# 25%      105.070000
# 50%      109.310000
# 75%      127.380000
# max     2224.410000

# %%
df_transado["daily_eq_demand"].describe()
# Out:
# count    3.888000e+03
# mean     9.465688e+06
# std      1.114707e+06
# min      6.916520e+06
# 25%      8.519658e+06
# 50%      9.510600e+06
# 75%      1.038452e+07
# max      1.192678e+07
# Name: daily_eq_demand, dtype: float64

# %%
df_final[["precio","cantidad_pos"]].describe()
# Out:
#               precio  cantidad_pos
# count  221832.000000  2.218320e+05
# mean      458.018612  1.872054e+05
# std       528.501790  2.640574e+05
# min         0.000000  0.000000e+00
# 25%       101.190000  1.800000e+04
# 50%       142.370000  6.300000e+04
# 75%       819.060000  2.410000e+05
# max      2603.340000  1.250000e+06

# %%
archivo_bolsa = "../datos/raw/Preciodebolsahorario.csv"
df_bolsa = pd.read_csv(archivo_bolsa, sep=",", encoding="utf-8")
df_bolsa
# Out:
#       CodigoVariable            FechaHora CodigoDuracion UnidadMedida Version  \
# 0             PB_Int  2025-06-01 00:00:00           PT1H      COP/kWh     TX2
# 1             PB_Int  2025-06-01 01:00:00           PT1H      COP/kWh     TX2
# 2             PB_Int  2025-06-01 02:00:00           PT1H      COP/kWh     TX2
# 3             PB_Int  2025-06-01 03:00:00           PT1H      COP/kWh     TX2
# 4             PB_Int  2025-06-01 04:00:00           PT1H      COP/kWh     TX2
# ...              ...                  ...            ...          ...     ...
# 59443         PB_Tie  2025-05-18 19:00:00           PT1H      COP/kWh     TXF
# 59444         PB_Tie  2025-05-18 20:00:00           PT1H      COP/kWh     TXF
# 59445         PB_Tie  2025-05-18 21:00:00           PT1H      COP/kWh     TXF
# 59446         PB_Tie  2025-05-18 22:00:00           PT1H      COP/kWh     TXF
# 59447         PB_Tie  2025-05-18 23:00:00           PT1H      COP/kWh     TXF
#
#         Valor
# 0      193.75
# 1      193.75
# 2      193.75
# 3      193.75
# 4      193.75
# ...       ...
# 59443  106.39
# 59444  106.39
# 59445  106.39
# 59446  102.64
# 59447  102.64
#
# [59448 rows x 6 columns]

# %%
df_bolsa_filtrado = df_bolsa[
    (df_bolsa["CodigoVariable"] == "PB_Nal") |
    (df_bolsa["Version"] == "TXF")
]
df_bolsa_filtrado
# Out:
#       CodigoVariable            FechaHora CodigoDuracion UnidadMedida Version  \
# 24            PB_Nal  2025-06-01 00:00:00           PT1H      COP/kWh     TX2
# 25            PB_Nal  2025-06-01 01:00:00           PT1H      COP/kWh     TX2
# 26            PB_Nal  2025-06-01 02:00:00           PT1H      COP/kWh     TX2
# 27            PB_Nal  2025-06-01 03:00:00           PT1H      COP/kWh     TX2
# 28            PB_Nal  2025-06-01 04:00:00           PT1H      COP/kWh     TX2
# ...              ...                  ...            ...          ...     ...
# 59443         PB_Tie  2025-05-18 19:00:00           PT1H      COP/kWh     TXF
# 59444         PB_Tie  2025-05-18 20:00:00           PT1H      COP/kWh     TXF
# 59445         PB_Tie  2025-05-18 21:00:00           PT1H      COP/kWh     TXF
# 59446         PB_Tie  2025-05-18 22:00:00           PT1H      COP/kWh     TXF
# 59447         PB_Tie  2025-05-18 23:00:00           PT1H      COP/kWh     TXF
#
#         Valor
# 24     110.77
# 25     110.77
# 26     110.77
# 27     110.77
# 28     110.77
# ...       ...
# 59443  106.39
# 59444  106.39
# 59445  106.39
# 59446  102.64
# 59447  102.64
#
# [27600 rows x 6 columns]

# %%
df_final.groupby("Fecha")["CodigoPlanta"].nunique().reset_index(name="n_planta")['n_planta'].value_counts()
# Out:
# n_planta
# 79    117
# Name: count, dtype: int64

# %%
df_final_daily = df_final.groupby('Fecha')['cantidad_pos'].sum().reset_index()
df_final_daily
# Out:
#           Fecha  cantidad_pos
# 0    2025-04-01  3.658460e+08
# 1    2025-04-02  3.685998e+08
# 2    2025-04-03  3.646588e+08
# 3    2025-04-04  3.630659e+08
# 4    2025-04-07  3.649803e+08
# ..          ...           ...
# 112  2025-09-03  3.318661e+08
# 113  2025-09-04  3.265878e+08
# 114  2025-09-05  3.271575e+08
# 115  2025-09-08  3.283627e+08
# 116  2025-09-09  3.347134e+08
#
# [117 rows x 2 columns]

# %%
df_transado['FechaHora'] = pd.to_datetime(df_transado['FechaHora'])
# Extraer solo la fecha
df_transado['Fecha'] = df_transado['FechaHora'].dt.date
# Agrupar por fecha (suma)
df_daily = df_transado.groupby('Fecha')['daily_eq_demand'].sum().reset_index()

# %%
df_daily
# Out:
#           Fecha  daily_eq_demand
# 0    2025-04-01        231947160
# 1    2025-04-02        231518930
# 2    2025-04-03        230498930
# 3    2025-04-04        227982000
# 4    2025-04-05        217050520
# ..          ...              ...
# 157  2025-09-05        248321680
# 158  2025-09-06        234167160
# 159  2025-09-07        208372420
# 160  2025-09-08        242142690
# 161  2025-09-09        249602100
#
# [162 rows x 2 columns]

# %%
df_bolsa
# Out:
#       CodigoVariable            FechaHora CodigoDuracion UnidadMedida Version  \
# 0             PB_Int  2025-06-01 00:00:00           PT1H      COP/kWh     TX2
# 1             PB_Int  2025-06-01 01:00:00           PT1H      COP/kWh     TX2
# 2             PB_Int  2025-06-01 02:00:00           PT1H      COP/kWh     TX2
# 3             PB_Int  2025-06-01 03:00:00           PT1H      COP/kWh     TX2
# 4             PB_Int  2025-06-01 04:00:00           PT1H      COP/kWh     TX2
# ...              ...                  ...            ...          ...     ...
# 59443         PB_Tie  2025-05-18 19:00:00           PT1H      COP/kWh     TXF
# 59444         PB_Tie  2025-05-18 20:00:00           PT1H      COP/kWh     TXF
# 59445         PB_Tie  2025-05-18 21:00:00           PT1H      COP/kWh     TXF
# 59446         PB_Tie  2025-05-18 22:00:00           PT1H      COP/kWh     TXF
# 59447         PB_Tie  2025-05-18 23:00:00           PT1H      COP/kWh     TXF
#
#         Valor
# 0      193.75
# 1      193.75
# 2      193.75
# 3      193.75
# 4      193.75
# ...       ...
# 59443  106.39
# 59444  106.39
# 59445  106.39
# 59446  102.64
# 59447  102.64
#
# [59448 rows x 6 columns]

# %%
# 1. Extraer solo la fecha
df_bolsa_filtrado["Fecha"] = pd.to_datetime(df_bolsa_filtrado["FechaHora"]).dt.date
# 2. Agrupar por Fecha y hacer promedio de Valor
df_daily_bolsa = (
    df_merged.groupby("Fecha")["Valor"]
    .mean()
    .reset_index(name="mean_valor")
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29140\346101769.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bolsa_filtrado["Fecha"] = pd.to_datetime(df_bolsa_filtrado["FechaHora"]).dt.date

# %%
df_daily_bolsa['Fecha'] = pd.to_datetime(df_daily_bolsa['Fecha'])
start = pd.Timestamp("2025-04-01")
end   = pd.Timestamp("2025-09-09")


df_daily_bolsa = df_daily_bolsa[
    (df_daily_bolsa["Fecha"] >= start) &
    (df_daily_bolsa["Fecha"] <= end)
].copy()

# %%
start = pd.Timestamp("2025-04-01")
end   = pd.Timestamp("2025-09-09")



df_merged["Fecha"] = pd.to_datetime(df_merged["Fecha"])

df_merged2 = df_merged[
    (df_merged["Fecha"] >= start) &
    (df_merged["Fecha"] <= end)
].copy()

# %%
df_merged2[['FechaHora', 'Valor', 'cantidad_pos','daily_eq_demand']]
# Out:
#                 FechaHora    Valor  cantidad_pos  daily_eq_demand
# 0     2025-07-24 00:00:00   111.95   14605560.00          8975940
# 1     2025-07-24 01:00:00   111.95   14632230.00          8670300
# 2     2025-07-24 02:00:00   111.95   14629750.00          8479780
# 3     2025-07-24 03:00:00   111.95   14638000.00          8375590
# 4     2025-07-24 04:00:00   112.27   14646000.00          8497020
# ...                   ...      ...           ...              ...
# 14251 2025-08-28 19:00:00  2218.51   13698992.52         11611160
# 14252 2025-08-28 20:00:00   503.76   13714567.79         11456300
# 14253 2025-08-28 21:00:00   398.76   13660693.41         10508100
# 14254 2025-08-28 22:00:00   353.76   13719237.25          9921170
# 14255 2025-08-28 23:00:00   353.76   13955845.32          9258280
#
# [14256 rows x 4 columns]

# %%
df_merged
# Out:
#       CodigoVariable           FechaHora CodigoDuracion UnidadMedida Version  \
# 0             PB_Nal 2025-07-24 00:00:00           PT1H      COP/kWh     TX4
# 1             PB_Nal 2025-07-24 01:00:00           PT1H      COP/kWh     TX4
# 2             PB_Nal 2025-07-24 02:00:00           PT1H      COP/kWh     TX4
# 3             PB_Nal 2025-07-24 03:00:00           PT1H      COP/kWh     TX4
# 4             PB_Nal 2025-07-24 04:00:00           PT1H      COP/kWh     TX4
# ...              ...                 ...            ...          ...     ...
# 14251         PB_Nal 2025-08-28 19:00:00           PT1H      COP/kWh     TXF
# 14252         PB_Nal 2025-08-28 20:00:00           PT1H      COP/kWh     TXF
# 14253         PB_Nal 2025-08-28 21:00:00           PT1H      COP/kWh     TXF
# 14254         PB_Nal 2025-08-28 22:00:00           PT1H      COP/kWh     TXF
# 14255         PB_Nal 2025-08-28 23:00:00           PT1H      COP/kWh     TXF
#
#          Valor  cantidad_pos  daily_eq_demand      Fecha
# 0       111.95   14605560.00          8975940 2025-07-24
# 1       111.95   14632230.00          8670300 2025-07-24
# 2       111.95   14629750.00          8479780 2025-07-24
# 3       111.95   14638000.00          8375590 2025-07-24
# 4       112.27   14646000.00          8497020 2025-07-24
# ...        ...           ...              ...        ...
# 14251  2218.51   13698992.52         11611160 2025-08-28
# 14252   503.76   13714567.79         11456300 2025-08-28
# 14253   398.76   13660693.41         10508100 2025-08-28
# 14254   353.76   13719237.25          9921170 2025-08-28
# 14255   353.76   13955845.32          9258280 2025-08-28
#
# [14256 rows x 9 columns]

# %%
df_daily_bolsa
# Out:
#          Fecha  mean_valor
# 0   2025-04-01  202.508611
# 1   2025-04-02  216.534861
# 2   2025-04-03  219.848333
# 3   2025-04-04  165.402222
# 4   2025-04-07  171.664000
# ..         ...         ...
# 112 2025-09-03  265.740417
# 113 2025-09-04  244.080625
# 114 2025-09-05  213.657292
# 115 2025-09-08  223.237292
# 116 2025-09-09  216.183021
#
# [117 rows x 2 columns]

# %%
df_daily
# Out:
#           Fecha  daily_eq_demand
# 0    2025-04-01        231947160
# 1    2025-04-02        231518930
# 2    2025-04-03        230498930
# 3    2025-04-04        227982000
# 4    2025-04-05        217050520
# ..          ...              ...
# 157  2025-09-05        248321680
# 158  2025-09-06        234167160
# 159  2025-09-07        208372420
# 160  2025-09-08        242142690
# 161  2025-09-09        249602100
#
# [162 rows x 2 columns]

# %%
df_final_daily
# Out:
#           Fecha  cantidad_pos
# 0    2025-04-01  3.658460e+08
# 1    2025-04-02  3.685998e+08
# 2    2025-04-03  3.646588e+08
# 3    2025-04-04  3.630659e+08
# 4    2025-04-07  3.649803e+08
# ..          ...           ...
# 112  2025-09-03  3.318661e+08
# 113  2025-09-04  3.265878e+08
# 114  2025-09-05  3.271575e+08
# 115  2025-09-08  3.283627e+08
# 116  2025-09-09  3.347134e+08
#
# [117 rows x 2 columns]
